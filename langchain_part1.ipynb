# %% [markdown]
# <a href="https://colab.research.google.com/github/pooshanchatterjee/langchain/blob/main/langchain_part1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install openai
# !pip install langchain
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.1/212.1 kB 3.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.9/75.9 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 76.9/76.9 kB 5.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 kB 7.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# llmx 0.0.15a0 requires cohere, which is not installed.
# llmx 0.0.15a0 requires tiktoken, which is not installed.
# tensorflow-probability 0.22.0 requires typing-extensions<4.6.0, but you have typing-extensions 4.9.0 which is incompatible.
# ...

# %%
import openai # to use openai llm
import langchain

# %%
SECRET_KEY = 'sk-QzFCxbzeKgB3BlbkFJeSARl4V4EJ'

# %%
from langchain.llms import OpenAI

# %%
# temperature parameter [0,1]. Higher temperature means more randomness and more
# creativity in every response

llm = OpenAI(openai_api_key = SECRET_KEY, temperature=0.3)
print(llm.predict("What is the capital of India ?"))
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The class `langchain_community.llms.openai.OpenAI` was deprecated in langchain-community 0.0.10 and will be removed in 0.2.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAI`.
#   warn_deprecated(
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `predict` was deprecated in LangChain 0.1.7 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-5-9d8a117d67b5> in <cell line: 5>()
#       3
#       4 llm = OpenAI(openai_api_key = SECRET_KEY, temperature=0.3)
# ...

# %%
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
prompt = PromptTemplate.from_template("What is the capital of {place}?")
llm = OpenAI(openai_api_key = SECRET_KEY, temperature=0.3)

chain = LLMChain(llm=llm, prompt=prompt)
output = chain.run("Punjab")
print(output)
# Out:
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py:117: LangChainDeprecationWarning: The function `run` was deprecated in LangChain 0.1.0 and will be removed in 0.2.0. Use invoke instead.
#   warn_deprecated(
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-9-352fac0ee497> in <cell line: 5>()
#       3
#       4 chain = LLMChain(llm=llm, prompt=prompt)
# ----> 5 output = chain.run("Punjab")
#       6 print(output)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         if isinstance(obj, type):
#
# ...

# %% [markdown]
# # Simple Sequential Chain

# %%
# LLM to get name of E-commerce store from product name

prompt = PromptTemplate.from_template("What is the name of the e-commerce that sells {products}?")
llm = OpenAI(openai_api_key = SECRET_KEY, temperature=0.3)

chain1 = LLMChain(llm=llm, prompt=prompt)

# product = "iphone"
# output = chain.run(product)
# print(output)

# %%
# LLm to get comma-seperated name of products from an e-commerce store name

prompt = PromptTemplate.from_template("What are the names of the products at {store}?")
llm = OpenAI(openai_api_key = SECRET_KEY, temperature=0.3)

chain2 = LLMChain(llm=llm, prompt=prompt)

# store = "Amazon"
# output = chain.run(product)
# print(output)

# %%
# creating overall chain from Simple Sequential Chain
from langchain.chains import SimpleSequentialChain
# chain = SimpleSequentialChain(chains = [chain1, chain2], input_variables = ["product", "store"])
chain = SimpleSequentialChain(chains = [chain1, chain2], verbose = True)
output = chain.run("candles")
print(output)
# Out:
# > Entering new SimpleSequentialChain chain...
# ---------------------------------------------------------------------------
# RateLimitError                            Traceback (most recent call last)
# <ipython-input-18-fb83ef181a59> in <cell line: 5>()
#       3 # chain = SimpleSequentialChain(chains = [chain1, chain2], input_variables = ["product", "store"])
#       4 chain = SimpleSequentialChain(chains = [chain1, chain2], verbose = True)
# ----> 5 output = chain.run("candles")
#       6 print(output)
#
# /usr/local/lib/python3.10/dist-packages/langchain_core/_api/deprecation.py in warning_emitting_wrapper(*args, **kwargs)
#     143                 warned = True
#     144                 emit_warning()
# --> 145             return wrapped(*args, **kwargs)
#     146
#     147         if isinstance(obj, type):
#
# /usr/local/lib/python3.10/dist-packages/langchain/chains/base.py in run(self, callbacks, tags, metadata, *args, **kwargs)
#     536             if len(args) != 1:
# ...
